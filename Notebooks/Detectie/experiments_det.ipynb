# %% [markdown]
# # 🔬 Studiu Experimental Binar: Triajul Pacienților (Sănătos vs. Bolnav)
#
# **Obiectiv:** Evaluarea capacității diferitelor arhitecturi de a distinge între un ochi sănătos (0) și unul cu orice formă de retinopatie diabetică (1).
#
# **Baseline-ul (Modelul de Control) ales pentru acest studiu este:**
# * **Dataset:** APTOS
# * **Model:** ResNet-50
# * **Loss:** BCEWithLogitsLoss standard (fără ponderare)
# * **Learning Rate:** 0.0001
# * **Rezoluție:** 224x224 (299 pentru Inception)

# %% [markdown]
# ## Partea 1: Evaluarea Arhitecturilor (8 Experimente)
# Testăm capacitatea de extragere a trăsăturilor pentru cele 8 arhitecturi vizate. Deoarece problema este una binară, ne așteptăm la o convergență mai rapidă și la acurateți mai ridicate (>90%) comparativ cu studiul multi-clasă.

# %%
# 1. Baseline (ResNet-50)
# %run train_det.py --dataset aptos --model resnet50 --loss bce --lr 0.0001 --epochs 100 --batch_size 32 --num_workers 8
# Out:
# 🔥 Rulăm pe device: cuda | Model: resnet50 | Dataset: aptos
# Imagini train: 2930 | Imagini test: 366
#
# Începe antrenamentul...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File B:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\Notebooks\Detectie\train_det.py:170
#     167     sys.modules['__main__'].__spec__ = None
#     168 torch.multiprocessing.freeze_support()
# --> 170 main()
#
# File B:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\Notebooks\Detectie\train_det.py:85, in main()
#      82 model.train()
#      83 running_train_loss = 0.0
# ---> 85 for images, labels in train_loader:
#      86     images = images.to(device)
#      87     # Folosim view(-1, 1) pentru a fi 100% siguri că forma e [batch_size, 1] pt BCEWithLogits
#
# File b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\.venv\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1524, in _MultiProcessingDataLoaderIter._next_data(self)
#    1520 if self._shutdown or self._tasks_outstanding <= 0:
#    1521     raise AssertionError(
#    1522         "Invalid iterator state: shutdown or no outstanding tasks when fetching next data"
#    1523     )
# -> 1524 idx, data = self._get_data()
#    1525 self._tasks_outstanding -= 1
#    1526 if self._dataset_kind == _DatasetKind.Iterable:
#    1527     # Check for _IterableDatasetStopIteration
#
# File b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1483, in _MultiProcessingDataLoaderIter._get_data(self)
#    1479     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1480     # need to call `.task_done()` because we don't use `.join()`.
#    1481 else:
#    1482     while True:
# -> 1483         success, data = self._try_get_data()
#    1484         if success:
#    1485             return data
#
# File b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1310, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1297 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1298     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1299     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1307     # Returns a 2-tuple:
#    1308     #   (bool: whether successfully get data, any: data if successful else None)
#    1309     try:
# -> 1310         data = self._data_queue.get(timeout=timeout)
#    1311         return (True, data)
#    1312     except Exception as e:
#    1313         # At timeout and error, we manually check whether any worker has
#    1314         # failed. Note that this is the only mechanism for Windows to detect
#    1315         # worker failures.
#
# File C:\Program Files\Python314\Lib\multiprocessing\queues.py:111, in Queue.get(self, block, timeout)
#     109 if block:
#     110     timeout = deadline - time.monotonic()
# --> 111     if not self._poll(timeout):
#     112         raise Empty
#     113 elif not self._poll():
#
# File C:\Program Files\Python314\Lib\multiprocessing\connection.py:264, in _ConnectionBase.poll(self, timeout)
#     262 self._check_closed()
#     263 self._check_readable()
# --> 264 return self._poll(timeout)
#
# File C:\Program Files\Python314\Lib\multiprocessing\connection.py:363, in PipeConnection._poll(self, timeout)
#     360 if (self._got_empty_message or
#     361             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     362     return True
# --> 363 return bool(wait([self], timeout))
#
# File C:\Program Files\Python314\Lib\multiprocessing\connection.py:1135, in wait(object_list, timeout)
#    1132                 ready_objects.add(o)
#    1133                 timeout = 0
# -> 1135     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#    1136 finally:
#    1137     # request that overlapped reads stop
#    1138     for ov in ov_list:
#
# File C:\Program Files\Python314\Lib\multiprocessing\connection.py:1067, in _exhaustive_wait(handles, timeout)
#    1065 while L:
#    1066     short_L = L[:60] if len(L) > 60 else L
# -> 1067     res = _winapi.WaitForMultipleObjects(short_L, False, timeout)
#    1068     if res == WAIT_TIMEOUT:
#    1069         break
#
# KeyboardInterrupt:

# %%
# 2. ResNet-34 
# %run train_det.py --dataset aptos --model resnet34 --loss bce --lr 0.0001 --epochs 50 --batch_size 32 --num_workers 8

# %%
# 3. EfficientNet-B0
# %run train_det.py --dataset aptos --model efficientnet_b0 --loss bce --lr 0.0001 --epochs 50 --batch_size 32 --num_workers 8
# Out:
# 🔥 Începere experiment BINAR (0 vs 1)
# Device: cuda | Dataset: APTOS | Model: efficientnet_b0 | Loss: BCE
# Incarcare date...
# Imagini antrenare: 2930 | Imagini validare: 366
# Epoca 01 | Timp: 75s | Train Loss: 0.2545 Acc: 0.9205 | Val Loss: 0.0599 Acc: 0.9863
# Epoca 02 | Timp: 72s | Train Loss: 0.0776 Acc: 0.9751 | Val Loss: 0.0482 Acc: 0.9863
# Epoca 03 | Timp: 70s | Train Loss: 0.0551 Acc: 0.9823 | Val Loss: 0.0461 Acc: 0.9754
# Epoca 04 | Timp: 89s | Train Loss: 0.0495 Acc: 0.9833 | Val Loss: 0.0337 Acc: 0.9918
# Epoca 05 | Timp: 90s | Train Loss: 0.0350 Acc: 0.9877 | Val Loss: 0.0358 Acc: 0.9863
# Epoca 06 | Timp: 89s | Train Loss: 0.0326 Acc: 0.9891 | Val Loss: 0.0344 Acc: 0.9918
# Epoca 07 | Timp: 89s | Train Loss: 0.0255 Acc: 0.9894 | Val Loss: 0.0281 Acc: 0.9918
# Epoca 08 | Timp: 88s | Train Loss: 0.0233 Acc: 0.9918 | Val Loss: 0.0275 Acc: 0.9945
# Epoca 09 | Timp: 87s | Train Loss: 0.0192 Acc: 0.9932 | Val Loss: 0.0522 Acc: 0.9809
# Epoca 10 | Timp: 82s | Train Loss: 0.0139 Acc: 0.9956 | Val Loss: 0.0383 Acc: 0.9945
# Epoca 11 | Timp: 68s | Train Loss: 0.0111 Acc: 0.9956 | Val Loss: 0.0442 Acc: 0.9863
# Epoca 12 | Timp: 70s | Train Loss: 0.0117 Acc: 0.9966 | Val Loss: 0.0305 Acc: 0.9945
# Epoca 13 | Timp: 72s | Train Loss: 0.0125 Acc: 0.9969 | Val Loss: 0.0485 Acc: 0.9836
# Epoca 14 | Timp: 67s | Train Loss: 0.0154 Acc: 0.9942 | Val Loss: 0.0297 Acc: 0.9918
# Epoca 15 | Timp: 71s | Train Loss: 0.0168 Acc: 0.9932 | Val Loss: 0.0317 Acc: 0.9973
# Epoca 16 | Timp: 69s | Train Loss: 0.0159 Acc: 0.9949 | Val Loss: 0.0409 Acc: 0.9945
# Epoca 17 | Timp: 70s | Train Loss: 0.0088 Acc: 0.9969 | Val Loss: 0.0528 Acc: 0.9863
# Epoca 18 | Timp: 70s | Train Loss: 0.0102 Acc: 0.9966 | Val Loss: 0.0504 Acc: 0.9918
# Epoca 19 | Timp: 75s | Train Loss: 0.0086 Acc: 0.9976 | Val Loss: 0.0413 Acc: 0.9918
# Epoca 20 | Timp: 72s | Train Loss: 0.0054 Acc: 0.9993 | Val Loss: 0.0384 Acc: 0.9945
# Epoca 21 | Timp: 73s | Train Loss: 0.0063 Acc: 0.9973 | Val Loss: 0.0377 Acc: 0.9918
# Epoca 22 | Timp: 76s | Train Loss: 0.0042 Acc: 0.9993 | Val Loss: 0.0354 Acc: 0.9945
# Epoca 23 | Timp: 70s | Train Loss: 0.0080 Acc: 0.9976 | Val Loss: 0.0503 Acc: 0.9918
# Epoca 24 | Timp: 66s | Train Loss: 0.0103 Acc: 0.9956 | Val Loss: 0.0476 Acc: 0.9945
# Epoca 25 | Timp: 71s | Train Loss: 0.0064 Acc: 0.9969 | Val Loss: 0.0536 Acc: 0.9918
# Epoca 26 | Timp: 70s | Train Loss: 0.0069 Acc: 0.9980 | Val Loss: 0.0383 Acc: 0.9945
# Epoca 27 | Timp: 69s | Train Loss: 0.0062 Acc: 0.9973 | Val Loss: 0.0472 Acc: 0.9945
# Epoca 28 | Timp: 67s | Train Loss: 0.0053 Acc: 0.9990 | Val Loss: 0.0674 Acc: 0.9863
# Epoca 29 | Timp: 67s | Train Loss: 0.0051 Acc: 0.9980 | Val Loss: 0.0633 Acc: 0.9945
# Epoca 30 | Timp: 67s | Train Loss: 0.0085 Acc: 0.9976 | Val Loss: 0.0690 Acc: 0.9918
# Epoca 31 | Timp: 67s | Train Loss: 0.0056 Acc: 0.9980 | Val Loss: 0.0421 Acc: 0.9945
# Epoca 32 | Timp: 65s | Train Loss: 0.0075 Acc: 0.9976 | Val Loss: 0.0341 Acc: 0.9973
# Epoca 33 | Timp: 68s | Train Loss: 0.0045 Acc: 0.9983 | Val Loss: 0.0237 Acc: 0.9918
# Epoca 34 | Timp: 68s | Train Loss: 0.0033 Acc: 0.9990 | Val Loss: 0.0254 Acc: 0.9973
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File B:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\Notebooks\Detectie\train_det.py:183
#     180     sys.modules['__main__'].__spec__ = None
#     182 torch.multiprocessing.freeze_support()
# --> 183 main()
#
# File B:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\Notebooks\Detectie\train_det.py:85, in main()
#      82 train_loss, train_correct, train_total = 0.0, 0, 0
#      84 loop_train = tqdm.tqdm(train_loader, desc=f"Epoca {epoch+1}/{args.epochs} [Train]", leave=False, ncols=100)
# ---> 85 for inputs, labels in loop_train:
#      86     inputs, labels = inputs.to(device), labels.to(device)
#      88     optimizer.zero_grad()
#
# File b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\.venv\Lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\.venv\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1524, in _MultiProcessingDataLoaderIter._next_data(self)
#    1520 if self._shutdown or self._tasks_outstanding <= 0:
#    1521     raise AssertionError(
#    1522         "Invalid iterator state: shutdown or no outstanding tasks when fetching next data"
#    1523     )
# -> 1524 idx, data = self._get_data()
#    1525 self._tasks_outstanding -= 1
#    1526 if self._dataset_kind == _DatasetKind.Iterable:
#    1527     # Check for _IterableDatasetStopIteration
#
# File b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1483, in _MultiProcessingDataLoaderIter._get_data(self)
#    1479     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1480     # need to call `.task_done()` because we don't use `.join()`.
#    1481 else:
#    1482     while True:
# -> 1483         success, data = self._try_get_data()
#    1484         if success:
#    1485             return data
#
# File b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1310, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1297 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1298     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1299     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1307     # Returns a 2-tuple:
#    1308     #   (bool: whether successfully get data, any: data if successful else None)
#    1309     try:
# -> 1310         data = self._data_queue.get(timeout=timeout)
#    1311         return (True, data)
#    1312     except Exception as e:
#    1313         # At timeout and error, we manually check whether any worker has
#    1314         # failed. Note that this is the only mechanism for Windows to detect
#    1315         # worker failures.
#
# File C:\Program Files\Python314\Lib\multiprocessing\queues.py:111, in Queue.get(self, block, timeout)
#     109 if block:
#     110     timeout = deadline - time.monotonic()
# --> 111     if not self._poll(timeout):
#     112         raise Empty
#     113 elif not self._poll():
#
# File C:\Program Files\Python314\Lib\multiprocessing\connection.py:264, in _ConnectionBase.poll(self, timeout)
#     262 self._check_closed()
#     263 self._check_readable()
# --> 264 return self._poll(timeout)
#
# File C:\Program Files\Python314\Lib\multiprocessing\connection.py:363, in PipeConnection._poll(self, timeout)
#     360 if (self._got_empty_message or
#     361             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     362     return True
# --> 363 return bool(wait([self], timeout))
#
# File C:\Program Files\Python314\Lib\multiprocessing\connection.py:1135, in wait(object_list, timeout)
#    1132                 ready_objects.add(o)
#    1133                 timeout = 0
# -> 1135     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#    1136 finally:
#    1137     # request that overlapped reads stop
#    1138     for ov in ov_list:
#
# File C:\Program Files\Python314\Lib\multiprocessing\connection.py:1067, in _exhaustive_wait(handles, timeout)
#    1065 while L:
#    1066     short_L = L[:60] if len(L) > 60 else L
# -> 1067     res = _winapi.WaitForMultipleObjects(short_L, False, timeout)
#    1068     if res == WAIT_TIMEOUT:
#    1069         break
#
# KeyboardInterrupt:

# %%
# 4. EfficientNet-B3
# %run train_det.py --dataset aptos --model efficientnet_b3 --loss bce --lr 0.0001 --epochs 50 --batch_size 32 --num_workers 8

# %%
# 5. DenseNet-121
# %run train_det.py --dataset aptos --model densenet121 --loss bce --lr 0.0001 --epochs 50 --batch_size 32 --num_workers 8

# %%
# 6. VGG-16 (Model mai sensibil la memorie, reducem batch-ul)
# %run train_det.py --dataset aptos --model vgg16 --loss bce --lr 0.0001 --epochs 15 --batch_size 16 --num_workers 8

# %%
# 7. Inception-v3 (Rezoluție 299 necesară)
# %run train_det.py --dataset aptos --model inception_v3 --loss bce --lr 0.0001 --img_size 299 --epochs 50 --batch_size 16 --num_workers 8

# %%
# 8. Inception-ResNet-v2 (Cel mai complex model)
# %run train_det.py --dataset aptos --model incres_v2 --loss bce --lr 0.0001 --img_size 299 --epochs 50 --batch_size 32 --num_workers 8

# %% [markdown]
# ## Partea 2: Evaluarea pe Baze de Date Diferite (4 Dataset-uri)
# Testăm robustețea deciziei DA/NU pe distribuții diferite de pacienți. APTOS este baseline-ul, dar IDRiD și EyePACS aduc provocări noi legate de iluminare, zgomot și calitatea imaginilor.

# %%
# 1. APTOS (Baseline - deja rulat)
# %run train_det.py --dataset aptos --model resnet50 --loss bce --lr 0.0001 --epochs 50 --batch_size 32 --num_workers 2

# 2. IDRiD (Calitate superioară, set mai mic)
# %run train_det.py --dataset idrid --model resnet50 --loss bce --lr 0.0001 --epochs 50 --batch_size 32 --num_workers 8

# %%
# 3. Messidor-2 (Standard medical strict)
# %run train_det.py --dataset messidor2 --model resnet50 --loss bce --lr 0.0001 --epochs 50 --batch_size 32 --num_workers 8

# %%
# 4. EyePACS (Dataset masiv, zgomot mare)
# %run train_det.py --dataset eyepacs --model resnet50 --loss bce --lr 0.0001 --epochs 15 --batch_size 32 --num_workers 8

# %% [markdown]
# ## Partea 3: Soluționarea Dezechilibrului de Clase (pos_weight)
# În mediul clinic real, avem mult mai mulți pacienți sănătoși decât bolnavi. În acest experiment, forțăm rețeaua să penalizeze mult mai sever o greșeală de tip "Fals Negativ" (adică să trimită acasă un pacient bolnav spunându-i că e sănătos).
#
# * `pos_weight 3.0` = O greșeală pe pacient bolnav costă cât 3 greșeli pe pacienți sănătoși.
# * `pos_weight 5.0` = O greșeală pe pacient bolnav costă de 5 ori mai mult.

# %%
# 1. BCE Standard (Fără ponderare, Baseline - deja rulat)
# %run train_det.py --dataset aptos --model resnet50 --loss bce --lr 0.0001 --epochs 15 --num_workers 0

# 2. BCE cu penalizare Moderată (x3)
# %run train_det.py --dataset aptos --model resnet50 --loss bce --pos_weight 3.0 --lr 0.0001 --epochs 50 --batch_size 32 --num_workers 8

# %%
# 3. BCE cu penalizare Severă (x5) - Observăm dacă modelul devine prea precaut (dă prea multe alarme false)
# %run train_det.py --dataset aptos --model resnet50 --loss bce --pos_weight 5.0 --lr 0.0001 --epochs 50 --batch_size 32 --num_workers 8

# %% [markdown]
# ## Partea 4: Sensibilitatea la Rata de Învățare
# Testăm dacă o problemă mai simplă (binară) beneficiază de o rată de învățare mai agresivă pentru a atinge convergența mai rapid.

# %%
# 1. Learning Rate = 0.0001 (Baseline - deja rulat)
# %run train_det.py --dataset aptos --model resnet50 --loss bce --lr 0.0001 --epochs 15 --num_workers 0

# 2. Learning Rate = 0.001 (Învățare rapidă)
# %run train_det.py --dataset aptos --model resnet50 --loss bce --lr 0.001 --epochs 50 --batch_size 32 --num_workers 8

# %%
# def vizualizare_predictii(model, device, test_csv_path, test_images_dir, num_imagini=6):
#     """
#     Alege aleatoriu un număr de imagini, face predicția și le afișează într-o grilă.
#     """
#     # 1. Încărcăm etichetele reale (Ground Truth)
#     test_df = pd.read_csv(test_csv_path)
    
#     # Alegem câteva rânduri la întâmplare
#     sample_df = test_df.sample(n=num_imagini)
    
#     # 2. Definim transformările pentru inferență
#     val_transforms = transforms.Compose([
#         transforms.Resize((224, 224)),
#         transforms.ToTensor(),
#         transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#     ])

#     model.eval()
    
#     # 3. Pregătim figura pentru afișare (ex: 2 rânduri, 3 coloane pentru 6 imagini)
#     fig = plt.figure(figsize=(15, 10))
    
#     with torch.no_grad():
#         for i, (index, row) in enumerate(sample_df.iterrows()):
#             img_name = str(row.iloc[0])
#             if not img_name.endswith('.png'):
#                 img_name += '.png'
                
#             img_path = os.path.join(test_images_dir, img_name)
#             adevarul_absolut = int(row.iloc[1]) # Ce a zis medicul (clasa reală)
            
#             # Încărcăm imaginea originală pentru afișare vizuală
#             try:
#                 image_pil = Image.open(img_path).convert('RGB')
#             except FileNotFoundError:
#                 print(f"Imaginea {img_name} nu a fost găsită.")
#                 continue

#             # Preprocesăm pentru model
#             image_tensor = val_transforms(image_pil).unsqueeze(0).to(device)

#             # Facem predicția
#             raw_output = model(image_tensor)
#             probability = torch.sigmoid(raw_output).item()
#             predictie_model = 1 if probability >= 0.5 else 0
            
#             # 4. Afișarea în grilă
#             ax = fig.add_subplot(2, 3, i+1) # Ajustează dacă schimbi numărul de imagini
#             ax.imshow(image_pil)
#             ax.axis('off') # Ascundem axele (X, Y) ca să arate curat
            
#             # Construim textul
#             diagnostic_real = "Bolnav" if adevarul_absolut == 1 else "Normal"
#             diagnostic_prezis = "Bolnav" if predictie_model == 1 else "Normal"
            
#             titlu = f"Real: {diagnostic_real} | Prezis: {diagnostic_prezis}\nÎncredere: {probability*100:.1f}%"
            
#             # Colorăm verde dacă e corect, roșu dacă a greșit
#             culoare = "green" if adevarul_absolut == predictie_model else "red"
#             ax.set_title(titlu, color=culoare, fontsize=12, fontweight='bold')

#     plt.tight_layout()
#     plt.show()

# # ==========================================
# # Apelarea funcției de vizualizare pe Kaggle:
# # ==========================================
# vizualizare_predictii(model, device, test_csv, test_dir, num_imagini=6)
