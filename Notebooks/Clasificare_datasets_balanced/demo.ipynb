# %%
# %run train.py --model incres_v2 --loss_name focal_loss --epochs 1 --batch_size 32 --num_workers 8 --lr 0.0001 --img_size 299

# %%
# %run train.py --model inception_v3 --loss_name focal_loss --epochs 1 --batch_size 32 --num_workers 8 --lr 0.0001 --img_size 299
# Out:
# 🔥 Config: inception_v3 | Loss: focal_loss | Opt: adam | LR: 0.0001
# 📊 Distribuție Date: TRAIN=34792 | VALIDARE=9940 | TESTARE=4971
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File B:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\Notebooks\Clasificare_datasets_balanced\train.py:229
#     227     sys.modules['__main__'].__spec__ = None
#     228 # torch.multiprocessing.freeze_support()
# --> 229 main()
#
# File B:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\Notebooks\Clasificare_datasets_balanced\train.py:90, in main()
#      88 outputs = model(imgs)
#      89 loss = compute_loss(criterion, outputs, labels, args.loss_name, device)
# ---> 90 loss.backward()
#      91 optimizer.step()
#      92 t_loss += loss.item()
#
# ...
