# %%
# See if train is on GPU or Cpu
import torch
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %% [markdown]
# # Inception-Resnet-V2
# Experimentul cel mai bun din experriments.ipynb: Aptos_ben_graham(_matched) + Diabetic_Balanced_Data
# Also resnet is for experiments and incres-v2 is my main

# %% [markdown]
# ## Aptos_ben_graham + balanced

# %%
# 1. 
# %run Clasificare_datasets_balanced/train.py --experiment balanced_aptos_to_balanced_aptos --model incres_v2 --loss_name focal_loss --gamma 1.5 --epochs 15 --batch_size 32 --num_workers 8 --lr 0.0001
# Out:
# Config: incres_v2 | Loss: focal_loss | Opt: adam | LR: 0.0001
# Experiment: balanced_aptos_to_balanced_aptos | TRAIN/VAL=combined | TEST=combined
# Balanced root: b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\datasets\Diabetic_Balanced_Data
# APTOS root:    b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\datasets\aptos\aptos_ben_graham
# Focal Loss activat cu gamma=1.5
# Distributie date: TRAIN=42292 | VALIDARE=10940 | TESTARE=6221
# Ep 01/15 | T_Loss: 0.5617 | V_Loss: 0.6708 | V_Acc: 60.6% | V_AUC: 0.8789 NOU BEST
# Durata epoca: 10.15 min
# Ep 02/15 | T_Loss: 0.4175 | V_Loss: 0.4119 | V_Acc: 68.0% | V_AUC: 0.9200 NOU BEST
# Durata epoca: 10.40 min
# Ep 03/15 | T_Loss: 0.3375 | V_Loss: 0.3858 | V_Acc: 72.0% | V_AUC: 0.9307 NOU BEST
# Durata epoca: 9.56 min
# Ep 04/15 | T_Loss: 0.2871 | V_Loss: 0.3429 | V_Acc: 74.6% | V_AUC: 0.9388 NOU BEST
# Durata epoca: 10.05 min
# Ep 05/15 | T_Loss: 0.2517 | V_Loss: 0.3546 | V_Acc: 75.4% | V_AUC: 0.9427 NOU BEST
# ...

# %% [markdown]
# # Aptos_ben_graham_matched + balanced

# %%
# 1. 
# %run Clasificare_datasets_balanced/train.py --experiment balanced_aptos_to_balanced_aptos --model incres_v2 --loss_name focal_loss --gamma 1.5 --epochs 15 --batch_size 32 --num_workers 8 --lr 0.0001
# Out:
# Config: incres_v2 | Loss: focal_loss | Opt: adam | LR: 0.0001
# Experiment: balanced_aptos_to_balanced_aptos | TRAIN/VAL=combined | TEST=combined
# Balanced root: b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\datasets\Diabetic_Balanced_Data
# APTOS root:    b:\Projects\Disertatie\Diabetic-Retinopathy-Classifier\datasets\aptos\aptos_ben_graham_matched
# Focal Loss activat cu gamma=1.5
# Distributie date: TRAIN=42292 | VALIDARE=10940 | TESTARE=6221
# ...
# Ep 01/15 | T_Loss: 0.5606 | V_Loss: 0.4992 | V_Acc: 62.1% | V_AUC: 0.8969 NOU BEST
# Durata epoca: 10.68 min
# Ep 02/15 | T_Loss: 0.4143 | V_Loss: 0.4070 | V_Acc: 69.3% | V_AUC: 0.9199 NOU BEST
# Durata epoca: 11.62 min
# Ep 03/15 | T_Loss: 0.3356 | V_Loss: 0.4391 | V_Acc: 69.0% | V_AUC: 0.9196
# Durata epoca: 10.73 min
# Ep 04/15 | T_Loss: 0.2841 | V_Loss: 1.3410 | V_Acc: 68.0% | V_AUC: 0.8665
# Durata epoca: 10.72 min
# Ep 05/15 | T_Loss: 0.2516 | V_Loss: 0.3553 | V_Acc: 74.2% | V_AUC: 0.9378 NOU BEST
# Durata epoca: 10.62 min
# ...
